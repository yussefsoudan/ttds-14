# %%
import os 
import re
from stemming.porter2 import stem
import pprint

# %%
# Break a book into paragraphs, turn each paragraph into words and consider only 
# those that contain more than 10 words
# and do not include any of the bad_chars 
def filterBook(filepath):   
#     introductions = ['Introduction','INTRODUCTION','Chapter 1','CHAPTER 1','PART I','Part I','ONE','One','PROLOGUE','Prologue']
    bad_chars = ['#','<','>','*','_',':','\n']

    filtered_pars = []
    quotes = []
    with open(filepath, 'r',encoding='utf-8') as read_file:
        
        text = read_file.read()
        paragraphs = text.split('\n\n')
        count=0
        for i,par in enumerate(paragraphs):
            if len(re.findall('\w+', par))>10 and not any(char in par for char in bad_chars):
                filtered_pars.append(par)

        for par in filtered_pars:
            quotes += [quote.strip() for quote in par.split('.')]
        
        print(f"Number of quotes in the book is {len(quotes)}")
    read_file.close()
#     print(quotes)
    return quotes

# %%
f=open("englishST.txt","r")
stopwords = [word for line in f for word in line.split()]
stopSet=set(stopwords)
f.close()

# %%
#Custom class to repressent quotes
# WIll probably contain more fields i.e a list of positions for a term?
class Quote:
    def __init__(self,id,length):
        self.id = id
        self.length = length
    
    def __str__(self):
        return f'Quote({self.id,self.length})'
    
    def __repr__(self):
        return str(self)

# %%
# Preprocessing and update of index

def preprocess(document):
    words = [stem(word.lower()) for word in re.findall('\w+', document) if not word.lower() in stopSet]
    return words

# Given the current index, the book and its quotes, update the collection index
def appendToIndex(index,bookname,quotes):
    # Index structure { term ->[docCount, {bookName -> [Quote]}, termFrequency] }
    for quoteId,quote in enumerate(quotes):
        terms=preprocess(quote)
        for term in terms: 
            if term in index:
                index[term][2] +=1 # update term freq

                # each term has a dictionary with books and quotes 
                if bookname not in index[term][1]:  # if bookname is not registered for this term 
                    index[term][0]+=1 # increase doc freq
                    index[term][1][bookname] = [Quote(quoteId,len(quote))]  # update set with docID
                else: # bookname exist in the dictionary
                    index[term][1][bookname].append(Quote(quoteId,len(quote))) # update the Quote list
                    
            else:
                index[term]=[]
                # doc frequency is 1. 
                index[term].append(1) 
                # The bookDictionary is initially empty. 
                index[term].append({})   
                # Initialize bookname entry 
                index[term][1][bookname] = [Quote(quoteId,len(quote))]
                # term frequency
                index[term].append(1)
    
    return index

# %%
def findISBN(filepath):
    f = open(filepath, "r",encoding='utf-8')
    text = f.read()

    # Try first with 'ISBN' included
    regex0 = re.compile("(?:ISBN(?:-1[03])?:? ?)(?:978(?:-|\s)?|979(?:-|\s)?)?(?:[0-9]{1,5}(?:-|\s)?)(?:[0-9]{1,7}(?:-|\s)?)(?:[0-9]{1,6}(?:-|\s)?)(?:[0-9X]{1}(?:-|\s)?)")    
    # Try without 'ISBN' and hyphen seperated
    regex1 = re.compile("(?:978(?:-)?|979(?:-)?)?(?:[0-9]{1,5}(?:-))(?:[0-9]{1,7}(?:-))(?:[0-9]{1,6}(?:-))(?:[0-9X]{1})")
    # Try without 'ISBN' and not seperated (must be of length 10 or 13; if 13, must start with 978 or 979)
    regex2 = re.compile("(?:978|979)?(?:[0-9]{9})(?:[0-9X]{1})")
    # Try without 'ISBN' and space seperated and ISBN-13 ONLY (sacrifice space seperated 10)
    regex3 = re.compile("(?:978\s|979\s)(?:[0-9]{1,5}\s)(?:[0-9]{1,7}\s)(?:[0-9]{1,6}\s)(?:[0-9X]{1})")

    if regex0.search(text):
        match = regex0.search(text).group(0)
        if ":" in match:
            return match.split(":")[1].strip()
        else:
            return match.split("ISBN")[1].strip()
    elif regex1.search(text):
        match = regex1.search(text).group(0)
        return match
    elif regex2.search(text):
        match = regex2.search(text).group(0)
        return match 
    elif regex3.search(text):
        match = regex3.search(text).group(0)
        return match
    return False

# %%
def readBooksDirectory():
    directory = r"C:/Users/Erodotos/Desktop/Year 4/TTDS/group-project/Book3"
#     folders = ['7', 'X', 'Y', 'Z']
    folders = ['Z']

    collection_idx = {}
    for folder in folders:
        subdir = directory + '/' + folder
        for filename in os.listdir(subdir):
            if filename.endswith(".txt"):
                filepath = subdir + '/' + filename
                authorIncluded = True if "-" in filename else False
                title = filename if not authorIncluded else filename.split("-")[0].strip()
                author = False if not authorIncluded else filename.split("-")[1].split(".")[0].strip()
                ISBN = findISBN(filepath)
                
                print(filename)
                print(ISBN)

                if ISBN and len(ISBN) >=10:
                    categories = getCategories(ISBN,filename) 
                    print(categories)
                else:
                    print('ERROR: No ISBN FOUND ')
                book_name = f"{title}-{author}"
                book_quotes = filterBook(filepath)
#                 collection_idx = appendToIndex(collection_idx,book_name,book_quotes)
                
                print('-'*100)
                

    
    pprint.pprint(collection_idx)


readBooksDirectory()
# Out:
# Z - Therese Anne Fowler.epub.txt
# 978-1-250-02865-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781250028655
# item idx 1
# Title Z: A Novel of Zelda Fitzgerald
# Authors ['Therese Fowler']
# ['Fiction']
# Number of quotes in the book is 8915
# ----------------------------------------------------------------------------------------------------
# Z Score Neurofeedback - Thatcher, Robert W., Lubar, Joe.epub.txt
# 978-0-12-801291-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9780128012918
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 3369
# ----------------------------------------------------------------------------------------------------
# Zabor - Kamel Daoud.epub.txt
# 978-2-330-08644-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9782330086442
# No match for given ISBN!
# item idx 0
# Title Zabor
# Authors ['Kamel Daoud']
# ['Fiction']
# Number of quotes in the book is 1995
# ----------------------------------------------------------------------------------------------------
# Zac Blasts Off.epub.txt
# 9781743581582
# https://www.googleapis.com/books/v1/volumes?q=isbn9781743581582
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 240
# ----------------------------------------------------------------------------------------------------
# Zac Unger - Never Look a Polar Bear in the Eye.epub.txt
# 978-0-306-82163-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9780306821639
# item idx 0
# Title Never Look a Polar Bear in the Eye
# Authors ['Zac Unger']
# ['Travel']
# Number of quotes in the book is 5379
# ----------------------------------------------------------------------------------------------------
# Zachary - Showstopper.epub.txt
# 978-0-7592-8579-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9780759285798
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 6495
# ----------------------------------------------------------------------------------------------------
# Zachary Auburn - How to Talk to Your Cat About Gun Safety.epub.txt
# 9780451494924
# https://www.googleapis.com/books/v1/volumes?q=isbn9780451494924
# Title How to Talk to Your Cat About Gun Safety
# Authors ['Zachary Auburn']
# ['Humor']
# Number of quotes in the book is 294
# ----------------------------------------------------------------------------------------------------
# Zachary Brown - Icarus Corps 01 - The Darkside War [retail].epub.txt
# 978-1-4814-3035-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781481430357
# item idx 0
# Title The Darkside War
# Authors ['Zachary Brown']
# ['Fiction']
# Number of quotes in the book is 6492
# ----------------------------------------------------------------------------------------------------
# Zachary Brown - Icarus Corps 02 - Titan_s Fall [retail].epub.txt
# 978-1-4814-3038-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781481430388
# item idx 0
# Title Titan's Fall
# Authors ['Zachary Brown']
# ['Fiction']
# Number of quotes in the book is 5841
# ----------------------------------------------------------------------------------------------------
# Zachary J. Cooper - I Simply Can_t Remember [retail].epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 188
# ----------------------------------------------------------------------------------------------------
# Zachary Jernigan - Jeroun 01 - No Return [retail].epub.txt
# 978-1-59780-457-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781597804578
# item idx 0
# Title No Return
# Authors ['Zachary Jernigan']
# ['Fiction']
# Number of quotes in the book is 11269
# ----------------------------------------------------------------------------------------------------
# Zachary Jernigan - Jeroun 02 - Shower of Stones [retail].epub.txt
# 978-1-59780-817-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9781597808170
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 6456
# ----------------------------------------------------------------------------------------------------
# Zachary Lazar - Evening_s Empire.epub.txt
# 978-0-316-07225-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780316072250
# item idx 0
# Title Evening's Empire
# Authors ['Zachary Lazar']
# ['Biography & Autobiography']
# Number of quotes in the book is 3047
# ----------------------------------------------------------------------------------------------------
# Zachary Lazar - Sway.epub.txt
# 0-316-11309-3
# https://www.googleapis.com/books/v1/volumes?q=isbn0316113093
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 3895
# ----------------------------------------------------------------------------------------------------
# Zachary Mason - Metamorphica.epub.txt
# 9780374208646
# https://www.googleapis.com/books/v1/volumes?q=isbn9780374208646
# Title Metamorphica
# Authors ['Zachary Mason']
# ['Fiction']
# Number of quotes in the book is 2980
# ----------------------------------------------------------------------------------------------------
# Zachary Taylor - John S. D. Eisenhower.epub.txt
# 9781429997416
# https://www.googleapis.com/books/v1/volumes?q=isbn9781429997416
# item idx 0
# Title Zachary Taylor
# Authors ['John S. D. Eisenhower']
# ['Biography & Autobiography']
# Number of quotes in the book is 3006
# ----------------------------------------------------------------------------------------------------
# Zach_s Law - Kay Hooper.epub.txt
# 978-0-345-52844-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780345528445
# item idx 0
# Title Zach's Law
# Authors ['Kay Hooper']
# ['Fiction']
# Number of quotes in the book is 3905
# ----------------------------------------------------------------------------------------------------
# Zack - Mons Kallentoft.epub.txt
# 978-91-7547-099-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9789175470993
# item idx 0
# Title Zack
# Authors ['Mons Kallentoft', 'Markus Lutteman']
# ['Fiction']
# Number of quotes in the book is 10029
# ----------------------------------------------------------------------------------------------------
# Zack Parsons - Liminal States [retail].epub.txt
# 978-0-8065-3551-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9780806535517
# item idx 0
# Title Liminal States
# Authors ['Zack Parsons']
# ['Fiction']
# Number of quotes in the book is 19161
# ----------------------------------------------------------------------------------------------------
# ZackOMalleyGreenburg-EmpireStateofMind_9781101476079.epub.txt
# 978-1-101-47607-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781101476079
# item idx 0
# Title Empire State of Mind
# Authors ["Zack O'Malley Greenburg"]
# ['Biography & Autobiography']
# Number of quotes in the book is 2153
# ----------------------------------------------------------------------------------------------------
# Zac_s Moon Trip.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 218
# ----------------------------------------------------------------------------------------------------
# Zadie Smith - On Beauty.epub.txt
# 978-1-1012-1811-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781101218112
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 7322
# ----------------------------------------------------------------------------------------------------
# Zadie Smith - The Autograph Man.epub.txt
# 978-1-4000-3443-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781400034437
# item idx 1
# Title The Autograph Man
# Authors ['Zadie Smith']
# ['Fiction']
# Number of quotes in the book is 5649
# ----------------------------------------------------------------------------------------------------
# Zadie the Sewing Fairy - Daisy Meadows.epub.txt
# 978-0-545-72535-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9780545725354
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 456
# ----------------------------------------------------------------------------------------------------
# ZAG - Marty Neumeier.epub.txt
# 0-321-42677-0
# https://www.googleapis.com/books/v1/volumes?q=isbn0321426770
# Title ZAG
# Authors ['Marty Neumeier']
# ['Computers']
# Number of quotes in the book is 1103
# ----------------------------------------------------------------------------------------------------
# Zagreb Noir - Ivan Srsen.epub.txt
# 978-1-61775-308-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781617753084
# item idx 0
# Title Zagreb Noir
# Authors ['Ivan Srsen']
# ['Croatia']
# Number of quotes in the book is 4310
# ----------------------------------------------------------------------------------------------------
# Zahav - Michael Solomonov.epub.txt
# 978-0-544-37328-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780544373280
# item idx 0
# Title Zahav
# Authors ['Michael Solomonov', 'Steven Cook']
# ['Cooking']
# Number of quotes in the book is 4250
# ----------------------------------------------------------------------------------------------------
# Zahn - Triplet.epub.txt
# 978-1-4532-7207-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781453272077
# item idx 0
# Title Triplet
# Authors ['Timothy Zahn']
# ['Fiction']
# Number of quotes in the book is 9097
# ----------------------------------------------------------------------------------------------------
# Zahn_Conquerors.Heritage.epub.txt
# 978-0-307-82242-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307822420
# item idx 0
# Title Conquerors' Heritage
# Authors ['Timothy Zahn']
# ['Fiction']
# Number of quotes in the book is 8454
# ----------------------------------------------------------------------------------------------------
# Zaide Bishop - Bones of Eden 01 - First Fall [retail].epub.txt
# 9781488032806
# https://www.googleapis.com/books/v1/volumes?q=isbn9781488032806
# item idx 0
# Title First Fall
# Authors ['Zaide Bishop']
# ['Fiction']
# Number of quotes in the book is 6778
# ----------------------------------------------------------------------------------------------------
# Zaide Bishop - Bones of Eden 02 - Second Heart [retail].epub.txt
# 9781488032813
# https://www.googleapis.com/books/v1/volumes?q=isbn9781488032813
# item idx 0
# Title Second Heart
# Authors ['Zaide Bishop']
# ['Fiction']
# Number of quotes in the book is 6613
# ----------------------------------------------------------------------------------------------------
# Zaide Bishop - Bones of Eden 03 - Third Wave [retail].epub.txt
# 9781488032820
# https://www.googleapis.com/books/v1/volumes?q=isbn9781488032820
# item idx 0
# Title Third Wave
# Authors ['Zaide Bishop']
# ['Fiction']
# Number of quotes in the book is 10660
# ----------------------------------------------------------------------------------------------------
# Zaire - Le Fanatisme ou Mahomet le prophet - Voltaire.epub.txt
# 9782081404915
# https://www.googleapis.com/books/v1/volumes?q=isbn9782081404915
# item idx 0
# Title Zaïre - Le Fanatisme ou Mahomet le prophète - Nanine ou L'Homme sans préjugés - Le Café ou L'Écossaise
# Authors ['Voltaire']
# ['Fiction']
# Number of quotes in the book is 1912
# ----------------------------------------------------------------------------------------------------
# Zaitoun - Yasmin Khan.epub.txt
# 978-1-324-00262-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781324002628
# Title Zaitoun: Recipes from the Palestinian Kitchen
# Authors ['Yasmin Khan']
# ['Cooking']
# Number of quotes in the book is 2868
# ----------------------------------------------------------------------------------------------------
# Zak George_s Dog Training Revol - Zak George.epub.txt
# 9781607748915
# https://www.googleapis.com/books/v1/volumes?q=isbn9781607748915
# Title Zak George's Dog Training Revolution
# Authors ['Zak George', 'Dina Roth Port']
# ['Pets']
# Number of quotes in the book is 2425
# ----------------------------------------------------------------------------------------------------
# Zak George_s Guide to a Well-Be - Zak George.epub.txt
# 9780399582417
# https://www.googleapis.com/books/v1/volumes?q=isbn9780399582417
# item idx 0
# Title Zak George's Guide to a Well-Behaved Dog
# Authors ['Zak George', 'Dina Roth Port']
# ['Pets']
# Number of quotes in the book is 2485
# ----------------------------------------------------------------------------------------------------
# Zak Smith - We Did Porn.epub.txt
# 978-0-982-05396-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780982053966
# item idx 0
# Title We Did Porn: Memoir and Drawings
# Authors ['Zak Smith']
# ['Art']
# Number of quotes in the book is 2737
# ----------------------------------------------------------------------------------------------------
# Zakir Hussain - Zakir Hussain.epub.txt
# 978-93-5277-049-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9789352770496
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 1532
# ----------------------------------------------------------------------------------------------------
# Zakka Style - Rashida Coleman-Hale.epub.txt
# 978-1-60705-417-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781607054177
# item idx 0
# Title Zakka Style
# No authors found!
# ['Crafts & Hobbies']
# Number of quotes in the book is 1750
# ----------------------------------------------------------------------------------------------------
# Zama - Antonio Di Benedetto.epub.txt
# 978-1-59017-735-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781590177358
# item idx 0
# Title Zama
# Authors ['Antonio Di Benedetto']
# ['Fiction']
# Number of quotes in the book is 4582
# ----------------------------------------------------------------------------------------------------
# Zamba - Ralph Helfer.epub.txt
# 9780061758027
# https://www.googleapis.com/books/v1/volumes?q=isbn9780061758027
# item idx 0
# Title Zamba
# Authors ['Ralph Helfer']
# ['Nature']
# Number of quotes in the book is 5874
# ----------------------------------------------------------------------------------------------------
# Zami - Geraldine Audre Lorde.epub.txt
# 978-0-89594-141-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780895941411
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 6333
# ----------------------------------------------------------------------------------------------------
# Zane - Brenda Jackson.epub.txt
# 9781460315415
# https://www.googleapis.com/books/v1/volumes?q=isbn9781460315415
# item idx 2
# Title Zane
# Authors ['Brenda Jackson']
# ['Fiction']
# Number of quotes in the book is 5156
# ----------------------------------------------------------------------------------------------------
# Zane and the Hurricane - Rodman Philbrick.epub.txt
# 978-0-545-63347-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780545633475
# item idx 0
# Title Zane and the Hurricane
# Authors ['Rodman Philbrick']
# ['Juvenile Fiction']
# Number of quotes in the book is 3451
# ----------------------------------------------------------------------------------------------------
# Zane Grey - Jeff Davis.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 175
# ----------------------------------------------------------------------------------------------------
# Zane Grey.epub.txt
# 978-0-252-03044-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9780252030444
# No registered ISBNs found!
# Title Zane Grey
# Authors ['Thomas H. Pauly']
# ['Biography & Autobiography']
# Number of quotes in the book is 4343
# ----------------------------------------------------------------------------------------------------
# Zane_ Ninja of Ice (Scholastic) - Greg Farshtey (retail).epub.txt
# 978-0-545-76598-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780545765985
# item idx 0
# Title Zane, Ninja of Ice (LEGO Ninjago: Chapter Book)
# Authors ['Greg Farshtey', 'Scholastic']
# ['Juvenile Fiction']
# Number of quotes in the book is 1025
# ----------------------------------------------------------------------------------------------------
# Zane_s Addicted - Zane.epub.txt
# 978-1-4767-0694-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781476706948
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 8158
# ----------------------------------------------------------------------------------------------------
# Zaniello, Tom - California_s Lamson Murder Mystery (2016) {9781439658192}.epub.txt
# 2016941431
# ERROR: No ISBN FOUND
# Number of quotes in the book is 1348
# ----------------------------------------------------------------------------------------------------
# Zanini De Vita, Oretta - Popes, Peasants, and Shepherds. Recipes and Lore from Rome and Lazio [trans. Maureen B. Fant] (U. of California Press, 2013).epub.txt
# 978-0-520-27154-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9780520271548
# item idx 0
# Title Popes, Peasants, and Shepherds
# Authors ['Oretta Zanini De Vita', 'Maureen B. Fant']
# ['Cooking']
# Number of quotes in the book is 5729
# ----------------------------------------------------------------------------------------------------
# Zanthodon Megapack, The - Lin Carter.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 18331
# ----------------------------------------------------------------------------------------------------
# Zapata - John Steinbeck.epub.txt
# 978-0-14-192351-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780141923512
# item idx 0
# Title Zapata
# Authors ['John Steinbeck']
# ['Fiction']
# Number of quotes in the book is 2398
# ----------------------------------------------------------------------------------------------------
# Zapatos italianos - Henning Mankell.epub.txt
# 978-84-8383-881-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9788483838815
# item idx 0
# Title Zapatos italianos
# Authors ['Henning Mankell']
# ['Fiction']
# Number of quotes in the book is 8143
# ----------------------------------------------------------------------------------------------------
# Zapped - Ann Louise Gittleman (2010).epub.txt
# 9780062014436
# https://www.googleapis.com/books/v1/volumes?q=isbn9780062014436
# item idx 0
# Title Zapped
# Authors ['Ann Louise Gittleman']
# ['Health & Fitness']
# Number of quotes in the book is 2346
# ----------------------------------------------------------------------------------------------------
# Zapped - Bob Berman.epub.txt
# 978-0-316-31131-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780316311311
# item idx 1
# Title Zapped
# Authors ['Bob Berman']
# ['Science']
# Number of quotes in the book is 2461
# ----------------------------------------------------------------------------------------------------
# Zapped - Sherwood Smith.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 1347
# ----------------------------------------------------------------------------------------------------
# Zatarain_America_s.First.Clash.with.Iran.epub.txt
# 978-1-935149-36-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781935149361
# item idx 0
# Title America's First Clash with Iran
# Authors ['Lee Allen Zatarain']
# ['History']
# Number of quotes in the book is 10290
# ----------------------------------------------------------------------------------------------------
# Zavist_ - Iurii Karlovich Oliesha.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 2689
# ----------------------------------------------------------------------------------------------------
# Zayn - ZAYN.epub.txt
# 978-1-5247-1872-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781524718725
# item idx 0
# Title Zayn
# Authors ['Zayn']
# ['Young Adult Nonfiction']
# Number of quotes in the book is 1055
# ----------------------------------------------------------------------------------------------------
# Zbig - Charles Gati.epub.txt
# 978-1-4214-0976-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781421409764
# item idx 0
# Title Zbig
# Authors ['Charles Gati']
# ['Biography & Autobiography']
# Number of quotes in the book is 2819
# ----------------------------------------------------------------------------------------------------
# ZBrush 4 Sculpting for Games - Manuel Scherer.epub.txt
# 978-1-849690-80-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781849690805
# Title ZBrush 4 Sculpting for Games
# Authors ['Manuel Scherer']
# ['Computers']
# Number of quotes in the book is 1451
# ----------------------------------------------------------------------------------------------------
# Zealot, The - Simon Scarrow.epub.txt
# 978-1-4683-1048-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781468310481
# item idx 0
# Title The Zealot
# Authors ['Simon Scarrow']
# ['Fiction']
# Number of quotes in the book is 10429
# ----------------------------------------------------------------------------------------------------
# Zealot-Aslan.epub.txt
# 978-0-679-60353-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780679603535
# item idx 1
# Title Zealot
# Authors ['Reza Aslan']
# ['Religion']
# Number of quotes in the book is 1779
# ----------------------------------------------------------------------------------------------------
# Zed - Joanna Kavenna.epub.txt
# 0000000000
# ERROR: No ISBN FOUND
# Number of quotes in the book is 6327
# ----------------------------------------------------------------------------------------------------
# Zeebrugge Raid - Philip Warner.epub.txt
# 978 1 84415 677 1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781844156771
# item idx 0
# Title Zeebrugge Raid
# Authors ['Philip Warner']
# ['History']
# Number of quotes in the book is 2050
# ----------------------------------------------------------------------------------------------------
# Zeh, Juli - Corpus Delicti.epub.txt
# 978-3-641-24270-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9783641242701
# item idx 4
# Title Corpus Delicti
# Authors ['Juli Zeh']
# ['Fiction']
# Number of quotes in the book is 4154
# ----------------------------------------------------------------------------------------------------
# Zeina - Nawal El Saadawi.epub.txt
# 978-0-86356-417-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9780863564178
# item idx 1
# Title Zeina
# Authors ['Nawāl Saʻdāwī']
# ['Fiction']
# Number of quotes in the book is 4880
# ----------------------------------------------------------------------------------------------------
# Zeitgeber - Greg Egan.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 729
# ----------------------------------------------------------------------------------------------------
# Zeitgeist - Bruce Sterling.epub.txt
# 978-0-307-79679-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307796790
# item idx 0
# Title Zeitgeist
# Authors ['Bruce Sterling']
# ['Fiction']
# Number of quotes in the book is 8029
# ----------------------------------------------------------------------------------------------------
# Zeitgeist - Todd Wiggins.epub.txt
# 978-1-62779-783-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781627797832
# item idx 0
# Title Zeitgeist
# Authors ['Todd Wiggins']
# ['Fiction']
# Number of quotes in the book is 6655
# ----------------------------------------------------------------------------------------------------
# Zeke and Ned - Larry McMurtry.epub.txt
# 978-1-4391-2816-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781439128169
# item idx 0
# Title Zeke and Ned
# Authors ['Larry McMurtry', 'Diana Ossana']
# ['Fiction']
# Number of quotes in the book is 13667
# ----------------------------------------------------------------------------------------------------
# Zeke Teflon - Free Radicals [retail].epub.txt
# 1-937276-05-8
# https://www.googleapis.com/books/v1/volumes?q=isbn1937276058
# item idx 0
# Title Free Radicals
# Authors ['Zeke Teflon']
# ['Fiction']
# Number of quotes in the book is 6976
# ----------------------------------------------------------------------------------------------------
# Zelda - Nancy Milford (retail).epub.txt
# 9780062032461
# https://www.googleapis.com/books/v1/volumes?q=isbn9780062032461
# item idx 0
# Title Zelda
# Authors ['Nancy Milford']
# ['Biography & Autobiography']
# Number of quotes in the book is 5345
# ----------------------------------------------------------------------------------------------------
# Zelda Fitzgerald - Save Me the Waltz.epub.txt
# 9781446418680
# https://www.googleapis.com/books/v1/volumes?q=isbn9781446418680
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 5941
# ----------------------------------------------------------------------------------------------------
# Zeldin, Theodore - An Intimate History of Humanity (1994_ Vintage, 1998).epub.txt
# 9781448161997
# https://www.googleapis.com/books/v1/volumes?q=isbn9781448161997
# item idx 0
# Title An Intimate History Of Humanity
# Authors ['Theodore Zeldin']
# ['Philosophy']
# Number of quotes in the book is 3605
# ----------------------------------------------------------------------------------------------------
# Zemindar - Valerie Fitzgerald.epub.txt
# 9781781859544
# https://www.googleapis.com/books/v1/volumes?q=isbn9781781859544
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 22131
# ----------------------------------------------------------------------------------------------------
# Zen - Roshi P. Kapleau.epub.txt
# 0-385-26104-7
# https://www.googleapis.com/books/v1/volumes?q=isbn0385261047
# No registered ISBNs found!
# Title Zen
# Authors ['Philip Kapleau']
# ['Philosophy']
# Number of quotes in the book is 2608
# ----------------------------------------------------------------------------------------------------
# Zen 24_7 - Philip Toshio Sudo.epub.txt
# 9780061980671
# https://www.googleapis.com/books/v1/volumes?q=isbn9780061980671
# item idx 0
# Title Zen 24/7
# Authors ['Philip T. Sudo']
# ['Religion']
# Number of quotes in the book is 1230
# ----------------------------------------------------------------------------------------------------
# Zen and Gone - Emily France.epub.txt
# 978-1-61695-857-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781616958572
# item idx 0
# Title Zen and Gone
# Authors ['Emily France']
# ['JUVENILE FICTION']
# Number of quotes in the book is 9192
# ----------------------------------------------------------------------------------------------------
# Zen and the Art of Creating Esc - Paula Y_.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 160
# ----------------------------------------------------------------------------------------------------
# Zen and the Art of Faking It - Jordan Sonnenblick.epub.txt
# 978-0-439-83707-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780439837071
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 2795
# ----------------------------------------------------------------------------------------------------
# Zen and the Art of Making a Living - Laurence G. Boldt.epub.txt
# 978-1-1012-0268-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781101202685
# item idx 0
# Title Zen and the Art of Making a Living
# Authors ['Laurence G. Boldt']
# ['Business & Economics']
# Number of quotes in the book is 10066
# ----------------------------------------------------------------------------------------------------
# Zen and the Art of Motorcycle M - Robert M. Pirsig.epub.txt
# 9780061907999
# https://www.googleapis.com/books/v1/volumes?q=isbn9780061907999
# item idx 0
# Title Zen and the Art of Motorcycle Maintenance
# Authors ['Robert M. Pirsig']
# ['Psychology']
# Number of quotes in the book is 11100
# ----------------------------------------------------------------------------------------------------
# Zen and the Art of Poker - Larry Phillips.epub.txt
# 978-1-1011-9197-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781101191972
# item idx 0
# Title Zen and the Art of Poker
# Authors ['Larry Phillips']
# ['Games & Activities']
# Number of quotes in the book is 1184
# ----------------------------------------------------------------------------------------------------
# Zen and the Magic of Photography - Wayne Rowe.epub.txt
# 978-1-933952-54-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9781933952543
# item idx 0
# Title Zen and the Magic of Photography
# Authors ['Wayne Rowe']
# ['COMPUTERS']
# Number of quotes in the book is 313
# ----------------------------------------------------------------------------------------------------
# Zen and Tonic - Jules Aron.epub.txt
# 978-1-58157-307-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781581573077
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 1002
# ----------------------------------------------------------------------------------------------------
# Zen Antics - Thomas Cleary.epub.txt
# 978-0-83483-014-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780834830141
# item idx 0
# Title Zen Antics
# Authors ['Thomas Cleary']
# ['Religion']
# Number of quotes in the book is 1896
# ----------------------------------------------------------------------------------------------------
# Zen Baggage - Red Pine.epub.txt
# 978-1-582-43978-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781582439785
# item idx 0
# Title Zen Baggage
# Authors ['Bill Porter']
# ['Religion']
# Number of quotes in the book is 6065
# ----------------------------------------------------------------------------------------------------
# Zen Bow, Zen Arrow - John Stevens.epub.txt
# 978-0-8348-2723-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9780834827233
# item idx 0
# Title Zen Bow, Zen Arrow
# Authors ['John Stevens']
# ['Religion']
# Number of quotes in the book is 563
# ----------------------------------------------------------------------------------------------------
# Zen Bridge - Keido Fukushima.epub.txt
# 9781614291978
# https://www.googleapis.com/books/v1/volumes?q=isbn9781614291978
# item idx 0
# Title Zen Bridge
# Authors ['Keido Fukushima']
# ['Body, Mind & Spirit']
# Number of quotes in the book is 2250
# ----------------------------------------------------------------------------------------------------
# Zen Camera - David Ulrich.epub.txt
# 9780399580338
# https://www.googleapis.com/books/v1/volumes?q=isbn9780399580338
# item idx 0
# Title Zen Camera
# Authors ['David Ulrich']
# ['Composition (Photography)']
# Number of quotes in the book is 2507
# ----------------------------------------------------------------------------------------------------
# Zen Cho (ed) - Cyberpunk_ Malaysia [retail].epub.txt
# 978-967-0750-89-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9789670750897
# item idx 0
# Title CYBERPUNK: MALAYSIA
# Authors ['Zen Cho']
# ['Fiction']
# Number of quotes in the book is 4963
# ----------------------------------------------------------------------------------------------------
# Zen Cho - Sorcerer Royal 01 - Sorcerer to the Crown [retail].epub.txt
# 978-0-698-40943-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9780698409439
# item idx 0
# Title Sorcerer to the Crown
# Authors ['Zen Cho']
# ['Fiction']
# Number of quotes in the book is 7908
# ----------------------------------------------------------------------------------------------------
# Zen Cho - Spirits Abroad (retail) (epub).epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 8256
# ----------------------------------------------------------------------------------------------------
# Zen City - Eliot Fintushel.epub.txt
# 978 1 78535 350 5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781785353505
# item idx 0
# Title Zen City
# Authors ['Eliot Fintushel']
# No categories found!
# []
# Number of quotes in the book is 3012
# ----------------------------------------------------------------------------------------------------
# Zen Dictionary - Ernest Wood.epub.txt
# 978-1-5040-2283-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781504022835
# item idx 0
# Title Zen Dictionary
# Authors ['Ernest Wood']
# ['Reference']
# Number of quotes in the book is 2701
# ----------------------------------------------------------------------------------------------------
# Zen Dogs.epub.txt
# 9780062459381
# https://www.googleapis.com/books/v1/volumes?q=isbn9780062459381
# item idx 0
# Title Zen Dogs
# Authors ['Alexandra Cearns']
# ['Photography']
# Number of quotes in the book is 50
# ----------------------------------------------------------------------------------------------------
# Zen Doodle - Oodles of Doodles.epub.txt
# 9781440336652
# https://www.googleapis.com/books/v1/volumes?q=isbn9781440336652
# item idx 0
# Title Zen Doodle Oodles of Doodles
# Authors ['Tonia Jenny']
# ['Art']
# Number of quotes in the book is 687
# ----------------------------------------------------------------------------------------------------
# Zen Doodle - Tonia Jenny.epub.txt
# 978-1-4403-3213-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781440332135
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 514
# ----------------------------------------------------------------------------------------------------
# Zen Doodling - David Williams.epub.txt
# 9781615647590
# https://www.googleapis.com/books/v1/volumes?q=isbn9781615647590
# item idx 0
# Title Idiot's Guides: Zen Doodling
# Authors ['David Williams']
# ['Art']
# Number of quotes in the book is 1670
# ----------------------------------------------------------------------------------------------------
# Zen Economics - Rob Urie.epub.txt
# 978-0-692-69225-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9780692692257
# item idx 0
# Title Zen Economics
# Authors ['Rob Urie']
# ['Business & Economics']
# Number of quotes in the book is 3938
# ----------------------------------------------------------------------------------------------------
# Zen Encounters with Loneliness - Terrance Keenan.epub.txt
# 1-61429-186-1
# https://www.googleapis.com/books/v1/volumes?q=isbn1614291861
# item idx 0
# Title Zen Encounters with Loneliness
# Authors ['Terrance Keenan']
# ['Biography & Autobiography']
# Number of quotes in the book is 2097
# ----------------------------------------------------------------------------------------------------
# Zen Essence - Thomas Cleary.epub.txt
# 978-0-8348-2927-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780834829275
# item idx 0
# Title Zen Essence
# Authors ['Thomas Cleary']
# ['Religion']
# Number of quotes in the book is 1989
# ----------------------------------------------------------------------------------------------------
# Zen food - Laure Kie.epub.txt
# 9782317011269
# https://www.googleapis.com/books/v1/volumes?q=isbn9782317011269
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 1246
# ----------------------------------------------------------------------------------------------------
# Zen for Christians - Kim Boykin.epub.txt
# 9780486824406
# https://www.googleapis.com/books/v1/volumes?q=isbn9780486824406
# Title Zen for Christians
# Authors ['Kim Boykin']
# ['Religion']
# Number of quotes in the book is 1550
# ----------------------------------------------------------------------------------------------------
# Zen Gardens - Mira Locher.epub.txt
# 978-1-4629-1049-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9781462910496
# item idx 0
# Title Zen Gardens
# Authors ['Mira Locher']
# ['Gardening']
# Number of quotes in the book is 2851
# ----------------------------------------------------------------------------------------------------
# Zen Gardens and Temples of Kyot - John Dougill.epub.txt
# 978-4-8053-1401-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9784805314012
# item idx 0
# Title Zen Gardens and Temples of Kyoto
# Authors ['John Dougill']
# ['Travel']
# Number of quotes in the book is 5416
# ----------------------------------------------------------------------------------------------------
# Zen Golf - Joseph Parent.epub.txt
# 978-0-385-50715-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9780385507158
# item idx 0
# Title Zen Golf
# Authors ['Joseph Parent']
# ['Sports & Recreation']
# Number of quotes in the book is 2323
# ----------------------------------------------------------------------------------------------------
# Zen in the Age of Anxiety - Tim Burkett.epub.txt
# 9781611804867
# https://www.googleapis.com/books/v1/volumes?q=isbn9781611804867
# Title Zen in the Age of Anxiety
# Authors ['Tim Burkett']
# ['Religion']
# Number of quotes in the book is 2720
# ----------------------------------------------------------------------------------------------------
# Zen in the Art of Writing - Ray Bradbury.epub.txt
# 9780008136512
# https://www.googleapis.com/books/v1/volumes?q=isbn9780008136512
# item idx 0
# Title Zen in the Art of Writing
# Authors ['Ray Bradbury']
# No categories found!
# []
# Number of quotes in the book is 1519
# ----------------------------------------------------------------------------------------------------
# Zen in the Martial Arts - Joe Hyams.epub.txt
# 978-0-307-75550-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307755506
# item idx 0
# Title Zen in the Martial Arts
# Authors ['Joe Hyams']
# ['Philosophy']
# Number of quotes in the book is 1359
# ----------------------------------------------------------------------------------------------------
# Zen Kittens - Gautama Buddha _ the editors of Mango Media.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 0
# ----------------------------------------------------------------------------------------------------
# Zen Koan as a Means of Attaining Enlight - Daisetz Suzuki.epub.txt
# 978-1-4629-0119-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781462901197
# item idx 0
# Title Zen Koan as a Means of Attaining Enlightenment
# Authors ['Dai Z. Suzuki']
# ['Philosophy']
# Number of quotes in the book is 2581
# ----------------------------------------------------------------------------------------------------
# Zen Kobudo - Mark Bishop.epub.txt
# 978-1-4629-0148-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781462901487
# item idx 0
# Title Zen Kobudo
# Authors ['Mark Bishop']
# ['Sports & Recreation']
# Number of quotes in the book is 1636
# ----------------------------------------------------------------------------------------------------
# Zen Lessons - Thomas Cleary.epub.txt
# 978-0-8348-2582-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780834825826
# item idx 0
# Title Zen Lessons
# No authors found!
# ['Religion']
# Number of quotes in the book is 2054
# ----------------------------------------------------------------------------------------------------
# Zen Living - Domyo Sater Burk.epub.txt
# 978-1-61564-432-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781615644322
# item idx 0
# Title Zen Living
# Authors ['Domyo Sater Burk']
# ['Philosophy']
# Number of quotes in the book is 4555
# ----------------------------------------------------------------------------------------------------
# Zen Master Poems - Allen, Dick.epub.txt
# 9781614292999
# https://www.googleapis.com/books/v1/volumes?q=isbn9781614292999
# item idx 0
# Title Zen Master Poems
# Authors ['Dick Allen']
# ['Poetry']
# Number of quotes in the book is 73
# ----------------------------------------------------------------------------------------------------
# Zen Master Raven - Robert Aitken.epub.txt
# 9781614293842
# https://www.googleapis.com/books/v1/volumes?q=isbn9781614293842
# Title Zen Master Raven
# Authors ['Robert Aitken']
# ['Religion']
# Number of quotes in the book is 748
# ----------------------------------------------------------------------------------------------------
# Zen Master Yunmen - Urs App.epub.txt
# 9781611805598
# https://www.googleapis.com/books/v1/volumes?q=isbn9781611805598
# Title Zen Master Yunmen
# Authors ['Urs App']
# ['Religion']
# Number of quotes in the book is 2285
# ----------------------------------------------------------------------------------------------------
# Zen Masters of China - McDaniel, Richard Bryan.epub.txt
# 978-1-4629-1050-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781462910502
# item idx 0
# Title Zen Masters Of China
# Authors ['Richard Bryan McDaniel']
# ['Religion']
# Number of quotes in the book is 3791
# ----------------------------------------------------------------------------------------------------
# Zen Masters of Japan - McDaniel, Richard Bryan.epub.txt
# 978-1-4629-1357-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781462913572
# item idx 0
# Title Zen Masters of Japan
# Authors ['Richard Bryan McDaniel']
# ['Religion']
# Number of quotes in the book is 3601
# ----------------------------------------------------------------------------------------------------
# Zen Meditation in Psychotherapy - Simpkins, C. Alexander, Simpkins, Annell.epub.txt
# 978-0-470-94826-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780470948262
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 5253
# ----------------------------------------------------------------------------------------------------
# Zen Meditation Plain and Simple - Albert Low.epub.txt
# 978-0-8048-3211-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9780804832113
# item idx 0
# Title Zen Meditation Plain and Simple
# Authors ['Albert Low']
# ['Self-Help']
# Number of quotes in the book is 1204
# ----------------------------------------------------------------------------------------------------
# Zen Mind, Beginner_s Mind - Shunryu Suzuki.epub.txt
# 978-0-8348-2129-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9780834821293
# item idx 0
# Title Zen Mind, Beginner's Mind
# Authors ['Shunryu Suzuki']
# ['Religion']
# Number of quotes in the book is 2126
# ----------------------------------------------------------------------------------------------------
# Zen Mind, Zen Horse - Allan J. Hamilton.epub.txt
# 978-1-60342-565-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9781603425650
# item idx 0
# Title Zen Mind, Zen Horse
# Authors ['Allan J. Hamilton']
# ['Nature']
# Number of quotes in the book is 3972
# ----------------------------------------------------------------------------------------------------
# Zen on the Trail - Christopher Ives.epub.txt
# 9781614294603
# https://www.googleapis.com/books/v1/volumes?q=isbn9781614294603
# item idx 0
# Title Zen on the Trail
# Authors ['Christopher Ives']
# ['Nature']
# Number of quotes in the book is 1306
# ----------------------------------------------------------------------------------------------------
# Zen Paintings in Edo Japan - Galit Aviman.epub.txt
# 978-1-4094-7042-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9781409470427
# Title Zen Paintings in Edo Japan (1600-1868)
# Authors ['Galit Aviman']
# ['Art']
# Number of quotes in the book is 2612
# ----------------------------------------------------------------------------------------------------
# Zen Poems of China and Japan - Lucien Stryk.epub.txt
# 978-0-8021-9826-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780802198266
# item idx 0
# Title Zen Poems of China and Japan
# Authors ['Lucien Stryk']
# ['Poetry']
# Number of quotes in the book is 642
# ----------------------------------------------------------------------------------------------------
# Zen Poetry - Lucien Stryk.epub.txt
# 978-0-8021-9824-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780802198242
# item idx 0
# Title Zen Poetry
# No authors found!
# ['Poetry']
# Number of quotes in the book is 184
# ----------------------------------------------------------------------------------------------------
# Zen Puppies - Gautama Buddha _ the editors of Mango Media.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 0
# ----------------------------------------------------------------------------------------------------
# Zen Putting - Joseph Parent.epub.txt
# 978-1-1012-1675-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9781101216750
# item idx 0
# Title Zen Putting
# Authors ['Joseph Parent']
# ['Sports & Recreation']
# Number of quotes in the book is 3310
# ----------------------------------------------------------------------------------------------------
# Zen Soup - Laurence G. Boldt.epub.txt
# 978-0-140-19560-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780140195606
# item idx 0
# Title Zen Soup
# Authors ['Laurence G. Boldt']
# ['Philosophy']
# Number of quotes in the book is 1456
# ----------------------------------------------------------------------------------------------------
# Zen Under Fire - Marianne Elliott.epub.txt
# 2013010912
# ERROR: No ISBN FOUND
# Number of quotes in the book is 7089
# ----------------------------------------------------------------------------------------------------
# Zen Women - Schireson, Grace_.epub.txt
# 978-0-861-71956-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9780861719563
# item idx 0
# Title Zen Women
# Authors ['Grace Schireson']
# ['Religion']
# Number of quotes in the book is 3544
# ----------------------------------------------------------------------------------------------------
# Zen Wrapped in Karma Dipped in - Unknown.epub.txt
# 978-1-57731-654-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781577316541
# item idx 0
# Title Zen Wrapped in Karma Dipped in Chocolate
# Authors ['Brad Warner']
# ['Biography & Autobiography']
# Number of quotes in the book is 3697
# ----------------------------------------------------------------------------------------------------
# Zen-Brain Horizons.epub.txt
# 978-0-262-02756-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9780262027564
# item idx 0
# Title Zen-Brain Horizons
# Authors ['James H. Austin']
# ['Body, Mind & Spirit']
# Number of quotes in the book is 875
# ----------------------------------------------------------------------------------------------------
# Zend.Framework2.0.epub.txt
# 978-1-78216-192-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781782161929
# item idx 0
# Title Zend Framework 2.0 by Example
# Authors ['Krishna Shasankar']
# ['COMPUTERS']
# Number of quotes in the book is 742
# ----------------------------------------------------------------------------------------------------
# Zendegi - Greg Egan.epub.txt
# 978-1-59780-174-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781597801744
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 6507
# ----------------------------------------------------------------------------------------------------
# Zenith Dream - F.T. Lukens.epub.txt
# 978-1-945053-76-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781945053764
# item idx 0
# Title Zenith Dream
# Authors ['F. T. Lukens']
# ['Young Adult Fiction']
# Number of quotes in the book is 9003
# ----------------------------------------------------------------------------------------------------
# Zenn Diagram - Wendy Brant.epub.txt
# 978-1-77138-856-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9781771388566
# item idx 0
# Title Zenn Diagram
# Authors ['Wendy Brant']
# ['Young Adult Fiction']
# Number of quotes in the book is 7043
# ----------------------------------------------------------------------------------------------------
# Zennor in Darkness - Helen Dunmore.epub.txt
# 978-0-14-193925-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9780141939254
# item idx 0
# Title Zennor in Darkness
# Authors ['Helen Dunmore']
# ['Fiction']
# Number of quotes in the book is 7041
# ----------------------------------------------------------------------------------------------------
# Zenon Kar_ Spaceball Star - Marilyn Sadler.epub.txt
# 978-0-307-80025-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307800251
# item idx 0
# Title Zenon Kar: Spaceball Star
# Authors ['Marilyn Sadler']
# ['Juvenile Fiction']
# Number of quotes in the book is 758
# ----------------------------------------------------------------------------------------------------
# Zeno_s Conscience - Italo Svevo (retail).epub.txt
# 0-375-41330-8
# https://www.googleapis.com/books/v1/volumes?q=isbn0375413308
# Title Lust
# Authors ['Elfriede Jelinek']
# No categories found!
# []
# Number of quotes in the book is 6474
# ----------------------------------------------------------------------------------------------------
# Zeno_s Paradox - Joseph Mazur.epub.txt
# 978-1-4406-3963-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9781440639630
# item idx 0
# Title Zeno's Paradox
# Authors ['Joseph Mazur']
# ['Science']
# Number of quotes in the book is 2935
# ----------------------------------------------------------------------------------------------------
# Zentangle Untangled - Kass Hall.epub.txt
# 978-1-4403-1826-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781440318269
# item idx 0
# Title Zentangle Untangled
# Authors ['Kass Hall']
# ['Art']
# Number of quotes in the book is 653
# ----------------------------------------------------------------------------------------------------
# Zen_ The Religion of the Samura - Kaiten Nukariya.epub.txt
# 978-1-775413-69-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781775413691
# item idx 0
# Title Zen: The Religion of the Samurai
# Authors ['Kaiten Nukariya']
# ['Religion']
# Number of quotes in the book is 2913
# ----------------------------------------------------------------------------------------------------
# Zeppelin vs British Home Defenc - Jon Guttman.epub.txt
# 978 1 4728 2 0
# https://www.googleapis.com/books/v1/volumes?q=isbn9781472820
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 521
# ----------------------------------------------------------------------------------------------------
# Zeppos First Wife - Gail Mazur.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 0
# ...
# item idx 0
# Title Zone One
# Authors ['Colson Whitehead']
# ['Fiction']
# Number of quotes in the book is 4316
# ----------------------------------------------------------------------------------------------------
# Zone One - Colson Whitehead.epub.txt
# 978-0-385-53501-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9780385535014
# item idx 0
# Title Zone One
# Authors ['Colson Whitehead']
# ['Fiction']
# Number of quotes in the book is 4324
# ----------------------------------------------------------------------------------------------------
# Zone to Win - Geoffrey A. Moore.epub.txt
# 978-1-68230-170-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9781682301708
# item idx 0
# Title Zone to Win
# Authors ['Geoffrey A. Moore']
# ['Business & Economics']
# Number of quotes in the book is 716
# ----------------------------------------------------------------------------------------------------
# Zong! - Philip, M. NourbeSe_ Boateng, S.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 0
# ----------------------------------------------------------------------------------------------------
# Zongmi on Chan - Jeffrey Lyle Broughton.epub.txt
# 978-0-231-51308-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780231513081
# No registered ISBNs found!
# item idx 1
# Title Zongmi on Chan
# Authors ['Jeffrey Lyle Broughton']
# ['Religion']
# Number of quotes in the book is 927
# ----------------------------------------------------------------------------------------------------
# Zoo - James Patterson _ Michael Ledwidge.epub.txt
# 978-0-316-09743-7
# https://www.googleapis.com/books/v1/volumes?q=isbn9780316097437
# item idx 0
# Title Zoo
# Authors ['James Patterson', 'Michael Ledwidge']
# ['Fiction']
# Number of quotes in the book is 7101
# ----------------------------------------------------------------------------------------------------
# Zoo 2 - James Patterson.epub.txt
# 978-0-316-36057-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9780316360579
# item idx 0
# Title Zoo 2
# Authors ['James Patterson']
# ['Fiction']
# Number of quotes in the book is 2692
# ----------------------------------------------------------------------------------------------------
# Zoo City - Lauren Beukes.epub.txt
# 978-0-85766-056-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780857660565
# item idx 0
# Title Zoo City
# Authors ['Lauren Beukes']
# ['Fiction']
# Number of quotes in the book is 6964
# ----------------------------------------------------------------------------------------------------
# Zoo Europa - Gert Nygaardshaug.epub.txt
# 978-82-02-58986-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9788202589868
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 6478
# ----------------------------------------------------------------------------------------------------
# Zoo Station - Christiane F.epub.txt
# 978-1-936976-22-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781936976225
# item idx 0
# Title Zoo Station
# Authors ['Christiane F.']
# ['Juvenile Nonfiction']
# Number of quotes in the book is 7858
# ----------------------------------------------------------------------------------------------------
# Zoo Station - David Downing.epub.txt
# 978-1-56947-971-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781569479711
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 7135
# ----------------------------------------------------------------------------------------------------
# Zoo Story.epub.txt
# 978-1-4013-2346-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9781401323462
# Title Zoo Story
# Authors ['Thomas French']
# ['Nature']
# Number of quotes in the book is 6021
# ----------------------------------------------------------------------------------------------------
# Zooarchaeology - Elizabeth J. Reitz.epub.txt
# 978-0-521-85726-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780521857260
# item idx 0
# Title Zooarchaeology
# Authors ['Elizabeth J. Reitz', 'Elizabeth S. Wing']
# ['Social Science']
# Number of quotes in the book is 4465
# ----------------------------------------------------------------------------------------------------
# Zoobiquity - Barbara Natterson-Horowitz.epub.txt
# 978-0-307-95838-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307958389
# item idx 0
# Title Zoobiquity
# Authors ['Barbara Natterson-Horowitz', 'Kathryn Bowers']
# ['Science']
# Number of quotes in the book is 3997
# ----------------------------------------------------------------------------------------------------
# Zooburbia - Tai Moses.epub.txt
# 978-1-937006-68-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9781937006686
# item idx 0
# Title Zooburbia
# Authors ['Tai Moses']
# ['Nature']
# Number of quotes in the book is 2221
# ----------------------------------------------------------------------------------------------------
# Zoographies - Calarco, Matthew_.epub.txt
# 978-0-231-51157-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780231511575
# No registered ISBNs found!
# item idx 1
# Title Zoographies
# Authors ['Matthew Calarco']
# ['Social Science']
# Number of quotes in the book is 468
# ----------------------------------------------------------------------------------------------------
# Zookeeper_s Wife, The - Diane Ackerman.epub.txt
# 978-0-393-06934-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9780393069341
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 3390
# ----------------------------------------------------------------------------------------------------
# Zoom - How Everything Moves - From Atoms and Galaxies to Blizzards and Bees - Bob Berman.epub.txt
# 978-0-316-21742-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780316217422
# item idx 0
# Title Zoom
# Authors ['Bob Berman']
# ['Science']
# Number of quotes in the book is 4206
# ----------------------------------------------------------------------------------------------------
# ZOOM - Vijay Vaitheeswaran.epub.txt
# 978-0-446-40832-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9780446408325
# item idx 0
# Title ZOOM
# Authors ['Mr. Vijay Vaitheeswaran', 'Mr. Iain Carson']
# ['Business & Economics']
# Number of quotes in the book is 3136
# ----------------------------------------------------------------------------------------------------
# Zoot Suit and Other Plays - Luis Valdez.epub.txt
# 978-1-55885-048-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781558850484
# No registered ISBNs found!
# Title Zoot Suit and Other Plays
# Authors ['Luis Valdez']
# ['Drama']
# Number of quotes in the book is 164
# ----------------------------------------------------------------------------------------------------
# Zoot-Suit Murders - Thomas Sanchez.epub.txt
# 978-0-307-49895-3
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307498953
# item idx 1
# Title Zoot-Suit Murders
# Authors ['Thomas Sanchez']
# ['Fiction']
# Number of quotes in the book is 3935
# ----------------------------------------------------------------------------------------------------
# ZooZical - Judy Sierra.epub.txt
# 978-0-375-98473-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780375984730
# item idx 0
# Title ZooZical
# Authors ['Judy Sierra']
# ['Juvenile Fiction']
# Number of quotes in the book is 0
# ----------------------------------------------------------------------------------------------------
# Zora and Langston_A Story of Friendship and Betrayal (Norton) - Yuval Taylor (retail).epub.txt
# 9780393243918
# https://www.googleapis.com/books/v1/volumes?q=isbn9780393243918
# Title Zora and Langston: A Story of Friendship and Betrayal
# Authors ['Yuval Taylor']
# ['Biography & Autobiography']
# Number of quotes in the book is 4034
# ----------------------------------------------------------------------------------------------------
# Zora Neale Hurston_ A Life in Letters (Anchor Books) - Carla Kaplan (retail).epub.txt
# 978-0-307-43036-6
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307430366
# item idx 0
# Title Zora Neale Hurston
# Authors ['Carla Kaplan, Ph.D.']
# ['Biography & Autobiography']
# Number of quotes in the book is 15613
# ----------------------------------------------------------------------------------------------------
# Zoraida Cordova - Vicious Deep 02 - The Savage Blue [retail].epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 11027
# ----------------------------------------------------------------------------------------------------
# Zoraida Cordova - Vicious Deep 03 - The Vast and Brutal Sea [retail].epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 8244
# ----------------------------------------------------------------------------------------------------
# Zorba the Greek - Nikos Kazantzakis.epub.txt
# 0-684-82554-6
# https://www.googleapis.com/books/v1/volumes?q=isbn0684825546
# item idx 0
# Title Zorba the Greek
# Authors ['Nikos Kazantzakis', 'Carl Wildman']
# ['Fiction']
# Number of quotes in the book is 8337
# ----------------------------------------------------------------------------------------------------
# Zoya - Danielle Steel.epub.txt
# 978-0-307-56706-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307567062
# item idx 0
# Title Zoya
# Authors ['Danielle Steel']
# ['Fiction']
# Number of quotes in the book is 12583
# ----------------------------------------------------------------------------------------------------
# Zoya Phan - Little Daughter.epub.txt
# 978-0-670-06968-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780670069682
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 7873
# ----------------------------------------------------------------------------------------------------
# Zoya_s Story - John Follain.epub.txt
# 978-0-062-03729-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9780062037299
# item idx 0
# Title Zoya's Story
# Authors ['John Follain', 'Rita Cristofari']
# ['Biography & Autobiography']
# Number of quotes in the book is 3244
# ----------------------------------------------------------------------------------------------------
# Zucked _ Waking Up to the Faceb - McNamee, Roger.epub.txt
# 9780525561361
# https://www.googleapis.com/books/v1/volumes?q=isbn9780525561361
# item idx 0
# Title Zucked
# Authors ['Roger McNamee']
# ['Political Science']
# Number of quotes in the book is 4033
# ----------------------------------------------------------------------------------------------------
# Zuckerman encadenado - Philip Roth.epub.txt
# 978-84-9032-756-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9788490327562
# item idx 0
# Title Zuckerman encadenado
# Authors ['Philip Roth']
# ['Fiction']
# Number of quotes in the book is 7319
# ----------------------------------------------------------------------------------------------------
# Zuckerman Unbound - Philip Roth.epub.txt
# 9781466846456
# https://www.googleapis.com/books/v1/volumes?q=isbn9781466846456
# item idx 0
# Title Zuckerman Unbound
# Authors ['Philip Roth']
# ['Fiction']
# Number of quotes in the book is 3836
# ----------------------------------------------------------------------------------------------------
# Zuckoff_Robert.Altman.epub.txt
# 978-0-307-27335-2
# https://www.googleapis.com/books/v1/volumes?q=isbn9780307273352
# item idx 0
# Title Robert Altman
# Authors ['Mitchell Zuckoff']
# ['Performing Arts']
# Number of quotes in the book is 5427
# ----------------------------------------------------------------------------------------------------
# Zui Gao Yuan Qin Zi Qing Cang Z - Ta Pin Qin Zi Ke Ti Zu.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 292
# ----------------------------------------------------------------------------------------------------
# Zui Hao Qing Qin Zi Dong Bei Zi - Ta Pin Qin Zi Ke Ti Zu.epub.txt
# 24-12-10-1
# ERROR: No ISBN FOUND
# Number of quotes in the book is 246
# ----------------------------------------------------------------------------------------------------
# Zukunft der Arbeit in Industrie 4.0 - Alfons Botthof.epub.txt
# 978-3-662-45914-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9783662459140
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 2915
# ----------------------------------------------------------------------------------------------------
# Zukunft der Arbeit – Eine praxisnahe Betrachtung (Wischmann, Hartmann).epub.txt
# 978-3-662-49265-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9783662492659
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 4477
# ----------------------------------------------------------------------------------------------------
# Zukunft war gestern - Henriette Nagel.epub.txt
# 978-3-945378-06-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9783945378069
# item idx 0
# Title Zukunft war gestern
# Authors ['Henriette Nagel']
# ['Performing Arts']
# Number of quotes in the book is 804
# ----------------------------------------------------------------------------------------------------
# Zuleika Dobson (Neversink) - Max Beerbohm (retail).epub.txt
# 978-1-61219-292-5
# https://www.googleapis.com/books/v1/volumes?q=isbn9781612192925
# No match for given ISBN!
# No match for given ISBN!
# []
# Number of quotes in the book is 5153
# ----------------------------------------------------------------------------------------------------
# Zum Baerenhaus - Andre Klein.epub.txt
# False
# ERROR: No ISBN FOUND
# Number of quotes in the book is 734
# ----------------------------------------------------------------------------------------------------
# Zumbo Files, The - Adriano Zumbo.epub.txt
# 978 1 74336 440 6
# https://www.googleapis.com/books/v1/volumes?q=isbn9781743364406
# item idx 0
# Title The Zumbo Files
# Authors ['Adriano Zumbo']
# ['Cooking']
# Number of quotes in the book is 3076
# ----------------------------------------------------------------------------------------------------
# Zumoterapia para las cuatro est - Leire Piriz.epub.txt
# 978-84-08-14119-8
# https://www.googleapis.com/books/v1/volumes?q=isbn9788408141198
# item idx 0
# Title Zumoterapia para las cuatro estaciones
# Authors ['Leire Piriz']
# ['Family & Relationships']
# Number of quotes in the book is 2547
# ----------------------------------------------------------------------------------------------------
# Zumwalt-Berman.epub.txt
# 978-0-06-169130-0
# https://www.googleapis.com/books/v1/volumes?q=isbn9780061691300
# item idx 0
# Title Zumwalt
# Authors ['Larry Berman']
# ['Biography & Autobiography']
# Number of quotes in the book is 11468
# ----------------------------------------------------------------------------------------------------
# Zundel_s Exit - Werner, Markus_ Hoffman, Michae.epub.txt
# 978-1-56478-921-1
# https://www.googleapis.com/books/v1/volumes?q=isbn9781564789211
# item idx 0
# Title Zundel's Exit
# Authors ['Markus Werner', 'Michael Hoffman']
# ['Fiction']
# Number of quotes in the book is 992
# ----------------------------------------------------------------------------------------------------
# Zygal - bp Nichol.epub.txt
# 978 1 77056 247 9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781770562479
# item idx 0
# Title Zygal
# Authors ['bp Nichol']
# ['Poetry']
# Number of quotes in the book is 67
# ----------------------------------------------------------------------------------------------------
# Zygmunt Miloszewski - A Grain of Truth (Teodor Szacki, Book 2).epub.txt
# 978-1-908524-03-4
# https://www.googleapis.com/books/v1/volumes?q=isbn9781908524034
# item idx 0
# Title A Grain of Truth
# Authors ['Zygmunt Miloszewski']
# ['Fiction']
# Number of quotes in the book is 7179
# ----------------------------------------------------------------------------------------------------
# ZZ Top - The Very Best of ZZ Top (Songbook).epub.txt
# 9781458485298
# https://www.googleapis.com/books/v1/volumes?q=isbn9781458485298
# item idx 0
# Title The Very Best of ZZ Top (Songbook)
# Authors ['ZZ Top']
# ['Music']
# Number of quotes in the book is 0
# ----------------------------------------------------------------------------------------------------
# ZZT - Anna Anthropy.epub.txt
# 978-1-940535-02-9
# https://www.googleapis.com/books/v1/volumes?q=isbn9781940535029
# item idx 0
# Title ZZT
# Authors ['Anna Anthropy']
# ['Computer games']
# Number of quotes in the book is 1199
# ----------------------------------------------------------------------------------------------------
# {}

# %%
https://www.googleapis.com/books/v1/volumes?q=isbn978-1-5040-4002-0

# %%
# importing the requests library 
import requests 

def getCategories(isbn,filename):

    # api-endpoint 
    URL = "https://www.googleapis.com/books/v1/volumes?q=isbn"
    ISBN = isbn.translate({ord(i): None for i in ' -:'}) # remove space, dashes or semicolons from isbn
    categories = []

    # location given here 
    request_url = URL + ISBN
    print(request_url)
    
    # Account for occasional failure of get request even though the book might exist
    for i in range(2):

        # sending get request and saving the response as response object 
        r = requests.get(url = request_url) 

        # extracting data in json format 
        data = r.json()
        items = 0
        
        # sometimes due to server error, the totalItems tag cannot be accessed
        # However, the normal case is that even if a book is not registered in the API, the
        # totalItems tag will be 0
        try:
            items = data['totalItems']
        except:
            print("No totalItems tag found, probably due to server error")
        
        if items>0:
            
            # Sometimes, the first item returned from the API is not the book with the given isbn
            # Search through the items list provided to find which item is the correct one 
            item_idx = 0
            for j in range(items):
                # industryIdentifiers tag might not exist
                try:
                    isbn10 = data['items'][j]['volumeInfo']['industryIdentifiers'][0]['identifier']
                    isbn13 = data['items'][j]['volumeInfo']['industryIdentifiers'][1]['identifier']
#                 
                    if (ISBN == isbn10 or ISBN == isbn13):
                        item_idx = j
                        print('item idx',item_idx)
                        break
                except:
                    print("No registered ISBNs found!")
            
            title = data['items'][item_idx]['volumeInfo']['title']
            print('Title',title)
            
            # author tag might not exist
            try:
                authors = data['items'][item_idx]['volumeInfo']['authors']
                print('Authors',authors)
            except:
                print("No authors found!") 
               
            # categories tag might not exist
            try:
                categories = data['items'][item_idx]['volumeInfo']['categories']
            except:
                print("No categories found!")
                
            break
        else:
            print("No match for given ISBN!")
        
    return categories

getCategories('978-1-84749-308-8',"")
# Out:
# https://www.googleapis.com/books/v1/volumes?q=isbn9781847493088
# item idx 1
# Title A Journey Around My Room
# Authors ['Xavier de Maistre']
# ['Fiction']
