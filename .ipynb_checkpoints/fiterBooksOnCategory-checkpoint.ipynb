# %%
import os 
from helperFunctions import findISBN,getBookMetadata
import pprint
from collections import Counter
from tqdm.auto import tqdm

# %%
def accumulateCategories():
    directory = r"/Users/humuyao/Downloads/Book3"
    folders = ['7', 'X', 'Y', 'Z']
#     folders = ['X']

    books_metadata = {}
    categories=[]
    booksWithFaultyISBN=0
    for folder in folders:
        subdir = directory + '/' + folder
        for filename in os.listdir(subdir):
            if filename.endswith(".txt"):
                filepath = subdir + '/' + filename
                text = open(filepath, "r",encoding='utf-8').read()

                print(filename)
                print(filepath)
                
                authorIncluded = True if "-" in filename else False
                title = filename if not authorIncluded else filename.split("-")[0].strip()
                author = False if not authorIncluded else filename.split("-")[1].split(".")[0].strip()
                ISBN = findISBN(text) # Books without ISBN have already been removed
                print(ISBN)
                
                if ISBN == False:
                    os.remove(filepath)
                    print('-'*100)
                    continue
                
                metadata = getBookMetadata(ISBN, title, author)

                # The ISBN does NOT match the Google ISBNs, remove book.
                if metadata == False:
                    booksWithFaultyISBN += 1
                    os.remove(filepath)
                    print('-'*100)
                    continue 
               

                books_metadata[title] = metadata
                categories+= metadata['categories']
                
#                 print(ISBN)

#                 if ISBN and len(ISBN) >=10:
#                     categories = getCategories(ISBN,filename) 
#                     print(categories)
#                 else:
#                     print('ERROR: No ISBN FOUND ')
#                 book_name = f"{title}-{author}"
#                 book_quotes = filterBook(filepath)
# #                 collection_idx = appendToIndex(collection_idx,book_name,book_quotes)
                
                print('-'*100)
                
    return books_metadata,categories

# %%
books_metadata, categories = accumulateCategories()
# Out:
# 7 lbs in 7 Days_ The Juice Master Diet (Updated Ed) - Jason Vale (2014).epub.txt
# /Users/humuyao/Downloads/Book3/7/7 lbs in 7 Days_ The Juice Master Diet (Updated Ed) - Jason Vale (2014).epub.txt
# 9780007436187
# ----------------------------------------------------------------------------------------------------
# 7.0 Tesla MRI Brain Atlas - 2010.epub.txt
# /Users/humuyao/Downloads/Book3/7/7.0 Tesla MRI Brain Atlas - 2010.epub.txt
# 978-1-60761-153-0
# ----------------------------------------------------------------------------------------------------
# 7 Money Rules for Life How to Take Control of Your Financial Future - Mary Hunt.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Money Rules for Life How to Take Control of Your Financial Future - Mary Hunt.epub.txt
# 978-1-4412-3610-4
# ----------------------------------------------------------------------------------------------------
# 747 - Joe Sutter.epub.txt
# /Users/humuyao/Downloads/Book3/7/747 - Joe Sutter.epub.txt
# 978-0-06-088241-9
# ----------------------------------------------------------------------------------------------------
# 791.4572 - Davis, Michael - Street Gang (ISBN 1440658757) [Viking, 2008].epub.txt
# /Users/humuyao/Downloads/Book3/7/791.4572 - Davis, Michael - Street Gang (ISBN 1440658757) [Viking, 2008].epub.txt
# 978-1-440-65875-4
# ----------------------------------------------------------------------------------------------------
# 7 Days at the Hot Corner - Terry Trueman.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Days at the Hot Corner - Terry Trueman.epub.txt
# 0-06-057494-1
# ----------------------------------------------------------------------------------------------------
# 7 Secrets of Neuron Leadership, The - W. Craig Reed.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Secrets of Neuron Leadership, The - W. Craig Reed.epub.txt
# 1505071359
# ----------------------------------------------------------------------------------------------------
# 7 Greeks - Guy Davenport.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Greeks - Guy Davenport.epub.txt
# 978-0-8112-1288-5
# ----------------------------------------------------------------------------------------------------
# 7 Laws of Network Marketing, The - Anthony Powell.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Laws of Network Marketing, The - Anthony Powell.epub.txt
# 978-1-61339-904-0
# ----------------------------------------------------------------------------------------------------
# 7 Secrets of Awakening the Highly Effective Four-Hour Giant, Today, The - The Gang.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Secrets of Awakening the Highly Effective Four-Hour Giant, Today, The - The Gang.epub.txt
# 978-0-06-222511-5
# ----------------------------------------------------------------------------------------------------
# 75 Habits for a Happy Marriage - Ashley David Bush.epub.txt
# /Users/humuyao/Downloads/Book3/7/75 Habits for a Happy Marriage - Ashley David Bush.epub.txt
# 1-4405-6226-1
# ----------------------------------------------------------------------------------------------------
# 78 Keys - Kristin Marra.epub.txt
# /Users/humuyao/Downloads/Book3/7/78 Keys - Kristin Marra.epub.txt
# 978-1-60282-517-8
# ----------------------------------------------------------------------------------------------------
# 7 - Jen Hatmaker.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 - Jen Hatmaker.epub.txt
# 978-1-4336-7296-5
# ----------------------------------------------------------------------------------------------------
# 7 Secrets of the Sensitive - Diane Kathrine.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Secrets of the Sensitive - Diane Kathrine.epub.txt
# False
# ----------------------------------------------------------------------------------------------------
# 7 Days - Deon Meyer.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Days - Deon Meyer.epub.txt
# 978-0-307-36021-2
# ----------------------------------------------------------------------------------------------------
# 7 Minutes to Fit - Brett Klika.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Minutes to Fit - Brett Klika.epub.txt
# 978-1-4521-3847-3
# ----------------------------------------------------------------------------------------------------
# 7 Treasures of Awakening - Joseph Goldstein.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Treasures of Awakening - Joseph Goldstein.epub.txt
# 978-1-62203-423-9
# ----------------------------------------------------------------------------------------------------
# 7 Secrets to an Awesome Marriage.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Secrets to an Awesome Marriage.epub.txt
# 978-0-310-34228-1
# ----------------------------------------------------------------------------------------------------
# 74 Seaside Avenue.epub.txt
# /Users/humuyao/Downloads/Book3/7/74 Seaside Avenue.epub.txt
# 9781460325322
# ----------------------------------------------------------------------------------------------------
# 7 More Comic Book Scripts - Robert T. Jeschonek.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 More Comic Book Scripts - Robert T. Jeschonek.epub.txt
# False
# ----------------------------------------------------------------------------------------------------
# 77 Dream Songs - John Berryman.epub.txt
# /Users/humuyao/Downloads/Book3/7/77 Dream Songs - John Berryman.epub.txt
# 978-0-374-53452-3
# ----------------------------------------------------------------------------------------------------
# 7 Billion.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Billion.epub.txt
# 978-1-4262-0942-0
# ----------------------------------------------------------------------------------------------------
# 7_Mantras_to_Excel_in_Exams.epub.txt
# /Users/humuyao/Downloads/Book3/7/7_Mantras_to_Excel_in_Exams.epub.txt
# 978-93-813-8419-0
# ----------------------------------------------------------------------------------------------------
# 77 - Guillermo Saccomanno.epub.txt
# /Users/humuyao/Downloads/Book3/7/77 - Guillermo Saccomanno.epub.txt
# 978-1-940953-93-9
# ----------------------------------------------------------------------------------------------------
# 7L - Michael J. Maher.epub.txt
# /Users/humuyao/Downloads/Book3/7/7L - Michael J. Maher.epub.txt
# 978-1-940363-21-9
# ----------------------------------------------------------------------------------------------------
# 740 Park - Michael Gross.epub.txt
# /Users/humuyao/Downloads/Book3/7/740 Park - Michael Gross.epub.txt
# 978-0-307-41876-0
# ----------------------------------------------------------------------------------------------------
# 7x7 Cooking -Hope Korenstein.epub.txt
# /Users/humuyao/Downloads/Book3/7/7x7 Cooking -Hope Korenstein.epub.txt
# 978-1-62087-688-6
# ----------------------------------------------------------------------------------------------------
# 7 Principles of an Evangelistic - Douglas M. Cecil.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Principles of an Evangelistic - Douglas M. Cecil.epub.txt
# 0-8024-0924-5
# ----------------------------------------------------------------------------------------------------
# 75 Masterpieces Every Christian Should Know - Terry Glaspey.epub.txt
# /Users/humuyao/Downloads/Book3/7/75 Masterpieces Every Christian Should Know - Terry Glaspey.epub.txt
# 978-1-4934-0046-1
# ----------------------------------------------------------------------------------------------------
# 75 Fun Fat-Quarter Quilts - Roxane Cerda.epub.txt
# /Users/humuyao/Downloads/Book3/7/75 Fun Fat-Quarter Quilts - Roxane Cerda.epub.txt
# 978-1-61745-151-5
# ----------------------------------------------------------------------------------------------------
# 7th Son - J.C. Hutchins.epub.txt
# /Users/humuyao/Downloads/Book3/7/7th Son - J.C. Hutchins.epub.txt
# 978-1-429-98381-5
# ----------------------------------------------------------------------------------------------------
# 7 Minutes in Heaven - Rhian Cahill.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Minutes in Heaven - Rhian Cahill.epub.txt
# 978-1-61921-978-6
# ----------------------------------------------------------------------------------------------------
# 77 Shadow Street (With Bonus Novella _The Moonlight Mind_) - Dean Koontz.epub.txt
# /Users/humuyao/Downloads/Book3/7/77 Shadow Street (With Bonus Novella _The Moonlight Mind_) - Dean Koontz.epub.txt
# 978-0-345-53236-7
# ----------------------------------------------------------------------------------------------------
# 7 Worst Mistakes People Make Wi - Jaqui Karr.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Worst Mistakes People Make Wi - Jaqui Karr.epub.txt
# 978-0-9881303-3-3
# ----------------------------------------------------------------------------------------------------
# 7 Ways to Be Her Hero.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Ways to Be Her Hero.epub.txt
# 978-0-5291-0220-1
# ----------------------------------------------------------------------------------------------------
# 7 Stories (Talonbooks) - Morris Panych (retail).epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Stories (Talonbooks) - Morris Panych (retail).epub.txt
# 978-0-88922-766-8
# ----------------------------------------------------------------------------------------------------
# 7 Secrets of Raising Girls Every Parent Must Know - Judy Reith.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Secrets of Raising Girls Every Parent Must Know - Judy Reith.epub.txt
# 978-1-78372-559-5
# ----------------------------------------------------------------------------------------------------
# 7 Keys to Comprehension - Susan Zimmermann.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Keys to Comprehension - Susan Zimmermann.epub.txt
# 978-0-307-45318-1
# ----------------------------------------------------------------------------------------------------
# 7 Deadly Women - Jamie I. Hall.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Deadly Women - Jamie I. Hall.epub.txt
# 978-1-4620-6016-0
# ----------------------------------------------------------------------------------------------------
# 7-Day Menu Planner For Dummies - Susan Nicholson.epub.txt
# /Users/humuyao/Downloads/Book3/7/7-Day Menu Planner For Dummies - Susan Nicholson.epub.txt
# 978-0-470-87857-6
# ----------------------------------------------------------------------------------------------------
# 7 Habits of Highly Effective People - Stephen R. Covey, The - Must Read Summaries.epub.txt
# /Users/humuyao/Downloads/Book3/7/7 Habits of Highly Effective People - Stephen R. Covey, The - Must Read Summaries.epub.txt
# False
# ----------------------------------------------------------------------------------------------------
# 7pm to 7am Sleeping Baby Routin - Charmian Mead.epub.txt
# /Users/humuyao/Downloads/Book3/7/7pm to 7am Sleeping Baby Routin - Charmian Mead.epub.txt
# 9781473555532
# ----------------------------------------------------------------------------------------------------
# 700 Sundays - Billy Crystal.epub.txt
# /Users/humuyao/Downloads/Book3/7/700 Sundays - Billy Crystal.epub.txt
# 978-0-7595-6934-8

# %%
categories = [cat.lower() for cat in categories]
print(len(categories))
pprint.pprint(Counter(categories))
# Out:
# 935
# Counter({'fiction': 226,
#          'health & fitness': 86,
#          'biography & autobiography': 72,
#          'religion': 51,
#          'business & economics': 45,
#          'history': 41,
#          'juvenile fiction': 37,
#          'self-help': 33,
#          'cooking': 32,
#          'family & relationships': 31,
#          'social science': 20,
#          'poetry': 19,
#          'young adult fiction': 17,
#          'body, mind & spirit': 16,
#          'travel': 14,
#          'juvenile nonfiction': 13,
#          'philosophy': 13,
#          'science': 13,
#          'humor': 11,
#          'political science': 10,
#          'computers': 10,
#          'psychology': 9,
#          'art': 9,
#          'sports & recreation': 8,
#          'crafts & hobbies': 7,
#          'nature': 6,
#          'music': 5,
#          'pets': 5,
#          'literary criticism': 4,
#          'performing arts': 4,
#          'language arts & disciplines': 4,
#          'literary collections': 4,
#          'reference': 4,
#          'photography': 4,
#          'comics & graphic novels': 3,
#          'house & home': 3,
#          'young adult nonfiction': 3,
#          'drama': 2,
#          'foreign language study': 2,
#          'australia': 2,
#          'true crime': 2,
#          'games & activities': 2,
#          'affirmation de soi': 1,
#          'argentina': 1,
#          'design': 1,
#          'yachting': 1,
#          'indic fiction (english)': 1,
#          'india': 1,
#          'canning and preserving': 1,
#          'cookbooks': 1,
#          'indoor gardening': 1,
#          'sasquatch': 1,
#          'adventure and adventurers': 1,
#          'hatha yoga': 1,
#          'cerebrovascular disease': 1,
#          'physical fitness': 1,
#          'education': 1,
#          'cancer': 1,
#          "children's stories": 1,
#          'antiques & collectibles': 1,
#          'baseball players': 1,
#          'medical': 1,
#          'bedtime': 1,
#          'artists': 1,
#          'autism': 1,
#          'hokkaido (japan)': 1,
#          'bento cooking': 1,
#          'architecture': 1,
#          'croatia': 1,
#          'composition (photography)': 1,
#          'gardening': 1,
#          'transportation': 1,
#          'chinese language': 1,
#          'judgments': 1,
#          'computer games': 1})

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
cats = Counter(categories)
print(cats)
# pprint.pprint(cats)
# f, ax = plt.subplots(figsize=(18,5))
# plt.bar(list(cats.keys()), list(cats.values()))
# plt.show()
# Out:
# Counter({'fiction': 226, 'health & fitness': 86, 'biography & autobiography': 72, 'religion': 51, 'business & economics': 45, 'history': 41, 'juvenile fiction': 37, 'self-help': 33, 'cooking': 32, 'family & relationships': 31, 'social science': 20, 'poetry': 19, 'young adult fiction': 17, 'body, mind & spirit': 16, 'travel': 14, 'juvenile nonfiction': 13, 'philosophy': 13, 'science': 13, 'humor': 11, 'political science': 10, 'computers': 10, 'psychology': 9, 'art': 9, 'sports & recreation': 8, 'crafts & hobbies': 7, 'nature': 6, 'music': 5, 'pets': 5, 'literary criticism': 4, 'performing arts': 4, 'language arts & disciplines': 4, 'literary collections': 4, 'reference': 4, 'photography': 4, 'comics & graphic novels': 3, 'house & home': 3, 'young adult nonfiction': 3, 'drama': 2, 'foreign language study': 2, 'australia': 2, 'true crime': 2, 'games & activities': 2, 'affirmation de soi': 1, 'argentina': 1, 'design': 1, 'yachting': 1, 'indic fiction (english)': 1, 'india': 1, 'canning and preserving': 1, 'cookbooks': 1, 'indoor gardening': 1, 'sasquatch': 1, 'adventure and adventurers': 1, 'hatha yoga': 1, 'cerebrovascular disease': 1, 'physical fitness': 1, 'education': 1, 'cancer': 1, "children's stories": 1, 'antiques & collectibles': 1, 'baseball players': 1, 'medical': 1, 'bedtime': 1, 'artists': 1, 'autism': 1, 'hokkaido (japan)': 1, 'bento cooking': 1, 'architecture': 1, 'croatia': 1, 'composition (photography)': 1, 'gardening': 1, 'transportation': 1, 'chinese language': 1, 'judgments': 1, 'computer games': 1})

# %%
accepted_cats = set(['fiction','biography & autobiography','juvenile fiction','poetry','young adult fiction',
                     'philosophy','young adult nonfiction','true crime','indic fiction (english)'])


# poetry -> probably should be included as it contains a lot of quotes and nice sentences, however, lines 
#             are disconnected contain \n\n chars etc. Might be a bit of a hasstle to include them

# philosophy -> again I am not sure if it should be included even though I expect people would know quotes 
#               from philosophy books. Some of them are malformed, not proper sentences titles etc. 
#               However, they do contain quotes

# literary collection -> seemed irrelevant 

# juvenile nonfiction -> rarely it included a story like a literature book but most of the time it wasnt a book that included quotes

# young adult nonficition -> seems betten than juvenile non fiction however we didnt have many samples so I cant say for sure

# drama  -> contains dialogues 

# true crime -> seems fine but again not a lot of samples 

not_made_the_cut = set(['juvenile nonfiction','literary collections','drama'])

# %%
counter = 0
cats = set(['indic fiction (english)'])
for key,metadata in tqdm(books_metadata.items()):

    book_cat = set([cat.lower() for cat in metadata['categories'] ])
    if (book_cat & cats):
        counter +=1
        print(f'{key}: {book_cat}')
        print('-'*20)
print(counter)
# Out:
# HBox(children=(IntProgress(value=0, max=902), HTML(value='')))
# Yamas Lieutenant and The Stone Witch.epub.txt: {'indic fiction (english)'}
# --------------------
#
# 1
